# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv('housing.csv')
df.head()
# Out:
#        Suburb          Address  Rooms   Type    Price               Method  \
# 0  Abbotsford  25 Bloomburg St      2  house  1035000        property sold
# 1  Abbotsford     5 Charles St      3  house  1465000  property sold prior
# 2  Abbotsford      55a Park St      4  house  1600000           vendor bid
# 3  Abbotsford     124 Yarra St      3  house  1876000        property sold
# 4  Abbotsford    98 Charles St      2  house  1636000        property sold
#
#   SellerG       Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  Biggin   4/2/2016       2.5      3067         2         1  0.0       156
# 1  Biggin   4/3/2017       2.5      3067         3         2  0.0       134
# 2  Nelson   4/6/2016       2.5      3067         3         1  2.0       120
# 3  Nelson   7/5/2016       2.5      3067         4         2  0.0       245
# 4  Nelson  8/10/2016       2.5      3067         2         1  2.0       256
#
# ...

# %%
plt.figure(figsize=(16, 6))
sns.scatterplot(x='Landsize', y='Price', data=df, hue='Type')
plt.title('Price vs Landsize',fontsize = 22)
plt.ylabel('Price (Hundred Thousand)', fontsize = 14)
plt.xlabel('Landsize (m^2)',fontsize = 14)
plt.show()

# %%
## Create a line chart that shows the year built along the x-axis and the average price per year on the y-axis. 
##You will need to use aggregation and group by to accomplish this. 
price_df = df.groupby('YearBuilt', as_index=False).agg({'Price': 'mean'})

price_df
# Out:
#      YearBuilt         Price
# 0       1830.0  8.550000e+05
# 1       1850.0  1.347000e+06
# 2       1854.0  3.310000e+06
# 3       1856.0  2.260000e+06
# 4       1860.0  1.980000e+06
# ..         ...           ...
# 130     2014.0  9.519831e+05
# 131     2015.0  1.255708e+06
# 132     2016.0  1.529026e+06
# 133     2017.0  1.041406e+06
# 134     2018.0  1.310000e+06
#
# [135 rows x 2 columns]

# %%
plt.figure(figsize=(10, 2))
plt.plot(price_df['YearBuilt'], age_df['Price'], )
plt.title('Price by Year Built', fontsize = 22)
plt.ylabel('Price (Hundred Thousand)',fontsize = 14)
plt.xlabel('Year Built',fontsize = 14)
plt.grid(True)
plt.show()

# %%
sns.barplot(x='Regionname', y='Price', data=df)
plt.show()

# %%
## Create a bar chart that shows the region on the x-axis and the average price of the property on the y-axis. 
##You will need to use aggregation and group by to accomplish this.

region_df = df.groupby('Regionname', as_index=False).agg({'Price': 'mean'})

# %%
plt.figure(figsize=(14, 6))
sns.barplot(x='Regionname', y='Price', data=df )
plt.title('Average property price by region', fontsize = 24)
plt.xlabel('Region', fontsize = 20)
plt.ylabel('Price', fontsize = 20)
plt.xticks(rotation=45)
plt.show()

# %%
# Create a histogram of property prices.
sns.histplot(x='Price', data=df, color = 'red')
plt.ylabel('Count', fontsize = 14)
plt.xlabel('Price', fontsize = 14)
plt.title('Property Prices', fontsize = 22)
plt.show()

# %%
df['Landsize_acres'] = df['Landsize'] * 0.000247105

# %%
df.head()
# Out:
#        Suburb          Address  Rooms   Type    Price               Method  \
# 0  Abbotsford  25 Bloomburg St      2  house  1035000        property sold
# 1  Abbotsford     5 Charles St      3  house  1465000  property sold prior
# 2  Abbotsford      55a Park St      4  house  1600000           vendor bid
# 3  Abbotsford     124 Yarra St      3  house  1876000        property sold
# 4  Abbotsford    98 Charles St      2  house  1636000        property sold
#
#   SellerG       Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0  Biggin   4/2/2016       2.5      3067  ...         1  0.0       156
# 1  Biggin   4/3/2017       2.5      3067  ...         2  0.0       134
# 2  Nelson   4/6/2016       2.5      3067  ...         1  2.0       120
# 3  Nelson   7/5/2016       2.5      3067  ...         2  0.0       245
# 4  Nelson  8/10/2016       2.5      3067  ...         1  2.0       256
#
#    BuildingArea  YearBuilt  CouncilArea             Regionname Propertycount  \
# ...

# %%
# Create a box plot that shows the years that each property was built on the x-axis and the region on the y-axis. 
# These box plots should be oriented horizontally
sns.boxplot(x='YearBuilt', y='Regionname', data=df, orient='h', color='black')
plt.ylabel(' Region Name', fontsize = 14, color = 'red')
plt.xlabel('Year Built', fontsize = 14, color = 'red')
plt.title('Year built across Regions', fontsize = 18, color = 'red')
plt.show()
